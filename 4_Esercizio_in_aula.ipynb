# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardonels/Colab-python/blob/main/4_Esercizio_in_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Analisi dei dati anagrafici dei dipendenti di un'azienda**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Inserisci in un dataframe il contenuto del file "dipendenti.csv".
#
#    Quante righe e quante colonne ci sono?

# %%
df = pd.read_csv("dipendenti.csv", sep=';')
df
#15 righe e 7 colonne
# Out:
#          Nome  Cognome   Età  Anni di esperienza            Dipartimento  \
# 0       Marco    Rossi   NaN                   2                 Vendite
# 1        Anna  Bianchi  32.0                   7  Information Technology
# 2        Luca    Verdi  28.0                   5                 Vendite
# 3        Sara     Neri  40.0                  12  Information Technology
# 4     Giorgio    Rossi  45.0                  20         Human Resources
# 5   Francesca  Ferrari   NaN                  15         Human Resources
# 6       Elena   Romano  34.0                   8  Information Technology
# 7      Simone   Gialli  30.0                   4                 Vendite
# 8   Valentina    Rossi  30.0                   9                 Vendite
# 9     Giorgio    Rossi  45.0                  20         Human Resources
# 10       Anna  Bianchi  32.0                   7                 Vendite
# 11       Sara  Bianchi  32.0                   7                 Vendite
# 12       Sara   Romano  33.0                   8  Information Technology
# 13     Simone   Gialli  30.0                   4                 Vendite
# 14  Valentina    Rossi  30.0                  12                 Vendite
#
#     Stipendio   Città
# 0       30000  Milano
# 1       45000    Roma
# 2       37000  Milano
# 3       62000    Roma
# 4       70000  Torino
# 5       58000    Roma
# 6       52000  Milano
# 7       33000  Napoli
# 8       32000  Napoli
# 9       70000  Torino
# 10      45000  Milano
# 11      25000    Roma
# 12      40000  Milano
# 13      33000  Napoli
# 14      42000  Milano

# %% [markdown]
# 2. Crea una nuova colonna chiamata **Livello Esperienza**, utilizzando la colonna **Anni di esperienza**. Se l'esperienza è minore di 5 anni, mappa il valore a "Junior", tra 5 e 10 a "Mid" e più di 10 a "Senior".

# %%
bins=[0,5,10,100]
exp_lvl=["Junior", "Mid", "Senior"]
pd.cut(df["Anni di esperienza"], bins, labels=exp_lvl)
# Out:
# 0     Junior
# 1        Mid
# 2     Junior
# 3     Senior
# 4     Senior
# 5     Senior
# 6        Mid
# 7     Junior
# 8        Mid
# 9     Senior
# 10       Mid
# 11       Mid
# 12       Mid
# 13    Junior
# 14    Senior
# Name: Anni di esperienza, dtype: category
# Categories (3, object): ['Junior' < 'Mid' < 'Senior']

# %%
def find_level(anni):
  if anni < 5:
    return 'Junior'
  elif anni >= 10:
    return 'Senior'
  else:
    return 'Mid'

# %%
df['Livello di esperienza']=df['Anni di esperienza'].map(find_level)
df
# Out:
#          Nome  Cognome   Età  Anni di esperienza            Dipartimento  \
# 0       Marco    Rossi   NaN                   2                 Vendite
# 1        Anna  Bianchi  32.0                   7  Information Technology
# 2        Luca    Verdi  28.0                   5                 Vendite
# 3        Sara     Neri  40.0                  12  Information Technology
# 4     Giorgio    Rossi  45.0                  20         Human Resources
# 5   Francesca  Ferrari   NaN                  15         Human Resources
# 6       Elena   Romano  34.0                   8  Information Technology
# 7      Simone   Gialli  30.0                   4                 Vendite
# 8   Valentina    Rossi  30.0                   9                 Vendite
# 9     Giorgio    Rossi  45.0                  20         Human Resources
# 10       Anna  Bianchi  32.0                   7                 Vendite
# 11       Sara  Bianchi  32.0                   7                 Vendite
# 12       Sara   Romano  33.0                   8  Information Technology
# 13     Simone   Gialli  30.0                   4                 Vendite
# 14  Valentina    Rossi  30.0                  12                 Vendite
#
#     Stipendio   Città Livello di esperienza
# 0       30000  Milano                Junior
# 1       45000    Roma                   Mid
# 2       37000  Milano                   Mid
# 3       62000    Roma                Senior
# 4       70000  Torino                Senior
# 5       58000    Roma                Senior
# 6       52000  Milano                   Mid
# 7       33000  Napoli                Junior
# 8       32000  Napoli                   Mid
# 9       70000  Torino                Senior
# 10      45000  Milano                   Mid
# 11      25000    Roma                   Mid
# 12      40000  Milano                   Mid
# 13      33000  Napoli                Junior
# 14      42000  Milano                Senior

# %% [markdown]
# 3. Sostituisci i nomi dei dipartimenti con le seguenti abbreviazioni: Vendite -> 'VEN', Information Technology -> 'IT', Human Resources -> 'HR'.

# %%
def label_short(dipartimento):
  if dipartimento == 'Vendite':
    return 'VEN'
  elif dipartimento == 'Information Technology':
    return 'IT'
  else:
    return 'HR'

# %%
df['Dipartimento']=df['Dipartimento'].map(label_short)
df
# Out:
#          Nome  Cognome   Età  Anni di esperienza Dipartimento  Stipendio  \
# 0       Marco    Rossi   NaN                   2          VEN      30000
# 1        Anna  Bianchi  32.0                   7           IT      45000
# 2        Luca    Verdi  28.0                   5          VEN      37000
# 3        Sara     Neri  40.0                  12           IT      62000
# 4     Giorgio    Rossi  45.0                  20           HR      70000
# 5   Francesca  Ferrari   NaN                  15           HR      58000
# 6       Elena   Romano  34.0                   8           IT      52000
# 7      Simone   Gialli  30.0                   4          VEN      33000
# 8   Valentina    Rossi  30.0                   9          VEN      32000
# 9     Giorgio    Rossi  45.0                  20           HR      70000
# 10       Anna  Bianchi  32.0                   7          VEN      45000
# 11       Sara  Bianchi  32.0                   7          VEN      25000
# 12       Sara   Romano  33.0                   8           IT      40000
# 13     Simone   Gialli  30.0                   4          VEN      33000
# 14  Valentina    Rossi  30.0                  12          VEN      42000
#
#      Città Livello di esperienza
# 0   Milano                Junior
# 1     Roma                   Mid
# 2   Milano                   Mid
# 3     Roma                Senior
# 4   Torino                Senior
# 5     Roma                Senior
# 6   Milano                   Mid
# 7   Napoli                Junior
# 8   Napoli                   Mid
# 9   Torino                Senior
# 10  Milano                   Mid
# 11    Roma                   Mid
# 12  Milano                   Mid
# 13  Napoli                Junior
# 14  Milano                Senior

# %% [markdown]
# 4. Crea un'altra colonna con i valori di età discretizzati in 5 gruppi, a quale gruppo di età appartiene la maggior parte dei dipendenti?

# %%
df['Età Discretizzata']=pd.cut(df['Età'],5)
df
# Out:
#          Nome  Cognome   Età  Anni di esperienza Dipartimento  Stipendio  \
# 0       Marco    Rossi   NaN                   2          VEN      30000
# 1        Anna  Bianchi  32.0                   7           IT      45000
# 2        Luca    Verdi  28.0                   5          VEN      37000
# 3        Sara     Neri  40.0                  12           IT      62000
# 4     Giorgio    Rossi  45.0                  20           HR      70000
# 5   Francesca  Ferrari   NaN                  15           HR      58000
# 6       Elena   Romano  34.0                   8           IT      52000
# 7      Simone   Gialli  30.0                   4          VEN      33000
# 8   Valentina    Rossi  30.0                   9          VEN      32000
# 9     Giorgio    Rossi  45.0                  20           HR      70000
# 10       Anna  Bianchi  32.0                   7          VEN      45000
# 11       Sara  Bianchi  32.0                   7          VEN      25000
# 12       Sara   Romano  33.0                   8           IT      40000
# 13     Simone   Gialli  30.0                   4          VEN      33000
# 14  Valentina    Rossi  30.0                  12          VEN      42000
#
#      Città Livello di esperienza Età Discretizzata
# 0   Milano                Junior               NaN
# 1     Roma                   Mid      (31.4, 34.8]
# 2   Milano                   Mid    (27.983, 31.4]
# 3     Roma                Senior      (38.2, 41.6]
# 4   Torino                Senior      (41.6, 45.0]
# 5     Roma                Senior               NaN
# 6   Milano                   Mid      (31.4, 34.8]
# 7   Napoli                Junior    (27.983, 31.4]
# 8   Napoli                   Mid    (27.983, 31.4]
# 9   Torino                Senior      (41.6, 45.0]
# 10  Milano                   Mid      (31.4, 34.8]
# 11    Roma                   Mid      (31.4, 34.8]
# 12  Milano                   Mid      (31.4, 34.8]
# 13  Napoli                Junior    (27.983, 31.4]
# 14  Milano                Senior    (27.983, 31.4]

# %%
df['Età Discretizzata'].value_counts()
# Out:
# Età Discretizzata
# (27.983, 31.4]    5
# (31.4, 34.8]      5
# (41.6, 45.0]      2
# (38.2, 41.6]      1
# (34.8, 38.2]      0
# Name: count, dtype: int64

# %% [markdown]
# 5. Sostituisci i valori mancanti della colonna età con il valore medio di età per i dipendenti dello stesso settore.

# %%
df['Età'] = df.groupby('Dipartimento')['Età'].transform(lambda x: x.fillna(x.mean()))
df
# Out:
#          Nome  Cognome        Età  Anni di esperienza Dipartimento  Stipendio  \
# 0       Marco    Rossi  30.285714                   2          VEN      30000
# 1        Anna  Bianchi  32.000000                   7           IT      45000
# 2        Luca    Verdi  28.000000                   5          VEN      37000
# 3        Sara     Neri  40.000000                  12           IT      62000
# 4     Giorgio    Rossi  45.000000                  20           HR      70000
# 5   Francesca  Ferrari  45.000000                  15           HR      58000
# 6       Elena   Romano  34.000000                   8           IT      52000
# 7      Simone   Gialli  30.000000                   4          VEN      33000
# 8   Valentina    Rossi  30.000000                   9          VEN      32000
# 9     Giorgio    Rossi  45.000000                  20           HR      70000
# 10       Anna  Bianchi  32.000000                   7          VEN      45000
# 11       Sara  Bianchi  32.000000                   7          VEN      25000
# 12       Sara   Romano  33.000000                   8           IT      40000
# 13     Simone   Gialli  30.000000                   4          VEN      33000
# 14  Valentina    Rossi  30.000000                  12          VEN      42000
#
#      Città Livello di esperienza Età Discretizzata
# 0   Milano                Junior               NaN
# 1     Roma                   Mid      (31.4, 34.8]
# 2   Milano                   Mid    (27.983, 31.4]
# 3     Roma                Senior      (38.2, 41.6]
# 4   Torino                Senior      (41.6, 45.0]
# 5     Roma                Senior               NaN
# 6   Milano                   Mid      (31.4, 34.8]
# 7   Napoli                Junior    (27.983, 31.4]
# 8   Napoli                   Mid    (27.983, 31.4]
# 9   Torino                Senior      (41.6, 45.0]
# 10  Milano                   Mid      (31.4, 34.8]
# 11    Roma                   Mid      (31.4, 34.8]
# 12  Milano                   Mid      (31.4, 34.8]
# 13  Napoli                Junior    (27.983, 31.4]
# 14  Milano                Senior    (27.983, 31.4]

# %% [markdown]
# 6. Verifica se, in media, lo stipendio di chi vive a Milano è superiore rispetto a quello di chi vive a Roma.

# %%
Roma=df[df['Città']=='Roma']['Stipendio'].mean()
Milano=df[df['Città']=='Milano']['Stipendio'].mean()
if(Roma<Milano):
  print(True)
else:
  print(False)
# Out:
# False
