# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardonels/Colab-python/blob/main/Esercizio_in_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Crea il DataFrame **vendite** che contiene la quantità di torte, biscotti e taralli (colonne) nei diversi giorni della settimana (righe).
#
#   Inserisci valori casuali compresi tra 5 e 50 (np.random.seed(100)).

# %%
import pandas as pd
import numpy as np
np.random.seed(100)

# %%
vendite=pd.DataFrame(np.random.randint(5,50, size=(7,3)), columns=['torte','biscotti', 'taralli'],index=['lun', 'mar', 'mer', 'gio', 'ven', 'sab', 'dom'])
vendite
# Out:
#      torte  biscotti  taralli
# lun      7        32       49
# mar      9        36        6
# mer     18        24       41
# gio      9        32        8
# ven     12         6       19
# sab     12        21        7
# dom     46        35       24

# %% [markdown]
# 2. Visualizza le vendite di torte durante tutta la settimana.

# %%
vendite['torte']
# Out:
# lun     7
# mar     9
# mer    18
# gio     9
# ven    12
# sab    12
# dom    46
# Name: torte, dtype: int64

# %% [markdown]
# 3. Ottieni le vendite del giovedi.

# %%
vendite[3:4]
# Out:
#      torte  biscotti  taralli
# gio      9        32        8

# %% [markdown]
# 4. Visualizza le vendite di biscotti e taralli dal mercoledì alla domenica.

# %%
vendite[['biscotti','taralli']][2:]
# Out:
#      biscotti  taralli
# mer        24       41
# gio        32        8
# ven         6       19
# sab        21        7
# dom        35       24

# %% [markdown]
# 5. Qual è il totale delle vendite per ogni prodotto durante la settimana?

# %%
vendite.sum()
# Out:
# torte       173
# biscotti    242
# taralli     154
# dtype: int64

# %% [markdown]
# 6. Qual è il giorno con il massimo delle vendite di torte?

# %%
vendite.max(axis=1).idxmax()
# Out:
# 'sab'

# %% [markdown]
# 7. Aggiungi la colonna **Totale Vendite Giorno** che rappresenta la somma delle vendite di tutti i prodotti per ciascun giorno.

# %%
vendite['totale_vendite']=vendite.sum(axis=1)
vendite
# Out:
#      torte  biscotti  taralli  totale_vendite
# lun     13        29        8              50
# mar     44        28       20              92
# mer     15        35       39              89
# gio      7        39       19              65
# ven     39        29       20              88
# sab     41        48       21             110
# dom     14        34       27              75

# %% [markdown]
# 8. Quali giorni hanno avuto un totale di vendite giornaliere superiori a 30?

# %%
vendite[(vendite['totale_vendite']>400)==True]
# Out:
# Empty DataFrame
# Columns: [torte, biscotti, taralli, totale_vendite]
# Index: []
